# %% [markdown]
# 1번
# 답:2 pickle

# %% [markdown]
# 2번
# 답:5 메모장에 저장된 파일, HTML 파일, 파이썬 코드 파일 등은 모두 텍스트 파일이다.

# %%
#3번
import pandas as pd
import easygui
from matplotlib import pyplot as plt
plt.rcParams['font.family'] = 'Gulim'
import pandas as pd
import easyguui
from mathplotlib impot pyplot as plt
plt.rcParms['font,family'] = 'Gulim'

# %%
data_file = easygui.fileopenbox()
parking = pd.read_csv(data_file)

# %%
parking.describe(include='all')
# Out:
#               연번   도로명   시 점            종 점 허용구분     연장(km) 허용시간 (주말-공휴일)  \
# count   23.00000    23    23             23   23  23.000000            23
# unique       NaN    19    20             21    2        NaN             4
# top          NaN  버드네길  갑천3가  하나로(아) 112동 뒤   편측        NaN   06:00~24:00
# freq         NaN     2     3              2   22        NaN            13
# mean    12.00000   NaN   NaN            NaN  NaN   0.261739           NaN
# std      6.78233   NaN   NaN            NaN  NaN   0.202656           NaN
# min      1.00000   NaN   NaN            NaN  NaN   0.100000           NaN
# 25%      6.50000   NaN   NaN            NaN  NaN   0.150000           NaN
# 50%     12.00000   NaN   NaN            NaN  NaN   0.240000           NaN
# 75%     17.50000   NaN   NaN            NaN  NaN   0.300000           NaN
# max     23.00000   NaN   NaN            NaN  NaN   1.100000           NaN
#
#               허용일자   비고
# count           23   23
# unique           3    4
# top     2009-12-17   체육
# freq            20   12
# mean           NaN  NaN
# std            NaN  NaN
# min            NaN  NaN
# 25%            NaN  NaN
# 50%            NaN  NaN
# 75%            NaN  NaN
# max            NaN  NaN

# %%
#4번
parking.plot.hist(y='연장(km)')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#5번
parking.loc[parking['연장(km)'] > 0.2].loc[parking['비고'] == '체육']
# Out:
#     연번    도로명          시 점               종 점 허용구분  연장(km) 허용시간 (주말-공휴일)  \
# 1    2  유등천동로          유등교           파라곤(아)앞   편측    0.40   06:00~24:00
# 15  16    선사로         갑천3가     하나로(아) 112동 뒤   편측    0.30   06:00~24:00
# 16  17   갑천대로         갑천3가     하나로(아) 112동 뒤   편측    0.30   06:00~24:00
# 19  20    대학로         유성구청              구성3가   편측    0.40   06:00~24:00
# 20  21   버드네길  세안(아)5동 맞은편               가장교   편측    0.24   07:00~20:00
# 21  22   버드네길          가장교  쌍용자동차서비스 프라자 맞은편   편측    0.26   07:00~20:00
#
#           허용일자  비고
# 1   2009-12-17  체육
# 15  2009-12-17  체육
# 16  2009-12-17  체육
# 19  2009-12-17  체육
# 20  2011-03-18  체육
# 21  2011-03-18  체육

# %%
parking_02 = parking.loc[parking['연장(km)'] > 0.2]
parking_02.loc[parking_02['비고'] == '체육']
# Out:
#     연번    도로명          시 점               종 점 허용구분  연장(km) 허용시간 (주말-공휴일)  \
# 1    2  유등천동로          유등교           파라곤(아)앞   편측    0.40   06:00~24:00
# 15  16    선사로         갑천3가     하나로(아) 112동 뒤   편측    0.30   06:00~24:00
# 16  17   갑천대로         갑천3가     하나로(아) 112동 뒤   편측    0.30   06:00~24:00
# 19  20    대학로         유성구청              구성3가   편측    0.40   06:00~24:00
# 20  21   버드네길  세안(아)5동 맞은편               가장교   편측    0.24   07:00~20:00
# 21  22   버드네길          가장교  쌍용자동차서비스 프라자 맞은편   편측    0.26   07:00~20:00
#
#           허용일자  비고
# 1   2009-12-17  체육
# 15  2009-12-17  체육
# 16  2009-12-17  체육
# 19  2009-12-17  체육
# 20  2011-03-18  체육
# 21  2011-03-18  체육
